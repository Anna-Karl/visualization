# %%
#load libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
#create a plot using sample data
np.random.seed(613)
x=np.arange(50)
y= np.random.randint(0,100,50)
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y)

# %%
#create a bar
fig, ax = plt.subplots(figsize=(5,3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
#create a line plot
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)
#add axis labels and titles
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years starts')
# Out:
# Text(0.5, 0, 'Years starts')

# %%
#create a histogram
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
#Style labels using font dictionaries
#create properties for labels
font1 = {'family':'sans-serif', 'color':'blue','size':20}
font2 = {'family':'monospace', 'color':'green','size':14}

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)
#modify labels and titles
ax.set_title('Total growth over time',fontdict=font1)
ax.set_ylabel('Total growth',fontdict=font2)
ax.set_xlabel('Years starts',fontdict=font2)
# Out:
# Text(0.5, 0, 'Years starts')

# %%
#modify data points
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y,
            marker = '*',
            color = 'indigo')

# %%
#add line connecting points
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
            marker = '*',
            color = 'indigo',
            linestyle = '--',
            linewidth = 2,
            markerfacecolor = '#000000')

# %%
#add grid
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
            marker = '*',
            color = 'indigo',
            linestyle = '--',
            linewidth = 2,
            markerfacecolor = '#000000')
ax.grid()

# %%
# Grid line
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
          marker ="*", 
          color = "indigo", 
          linestyle = "--",
          linewidth = 2,
           markeredgecolor = "#FA9359", 
           markerfacecolor = "#000000") 
ax.grid() # both vertical and horizontal grid lines
#ax.grid(axis = "x") # vertical grid lines
#ax.grid(axis = "y") # horizontal grid lines

# %%
#Activity (Python Graph Gallery)

# Initialize plot with polar coordinates.
plt.subplot(111, polar=True);

# %%
# Add a bar in the polar coordinates
plt.subplot(111, polar=True)
plt.bar(x=0, height=10, width=np.pi/2, bottom=5);

# %%
# Build a dataset
df = pd.DataFrame(
        {
            'Name': ['лепесток ' + str(i) for i in list(range(1, 51)) ],
            'Value': np.random.randint(low=10, high=100, size=50)
        })

# Show 3 first rows
df.head(3)
# Out:
#          Name  Value
# 0  лепесток 1     10
# 1  лепесток 2     65
# 2  лепесток 3     46

# %%
# set figure size
plt.figure(figsize=(20,10))

# plot polar axis
ax = plt.subplot(111, polar=True)

# remove grid
plt.axis('off')

# Set the coordinates limits
upperLimit = 100
lowerLimit = 30

# Compute max and min in the dataset
max = df['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white")

# %%
# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

import random

# Generate random colors for each bar
random_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in range(len(angles))]

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color=random_colors,
    alpha = 0.9,
)

# little space between the bar and the label
labelPadding = 4

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df["Name"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %%
# Build a dataset
df = pd.DataFrame(
        {
            'Name': ['item ' + str(i) for i in list(range(1, 51)) ],
            'Value': np.random.randint(low=10, high=100, size=50)
        })

# Reorder the dataframe
df = df.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df.index)+1))
angles = [element * width for element in indexes]
angles

# Define the colors
colors = ['#5e6985', '#d0abb5', '#eacfcb', '#fff5ef', '#91797e', '#a5999b']

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color=[colors[i % len(colors)] for i in range(len(angles))],
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df["Name"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %%
from matplotlib import cm

# Generate angles, heights, and widths
angles = np.linspace(0, 2 * np.pi, 10, endpoint=False)
heights = np.random.rand(10) * 10
width = [random.uniform(0.2, 0.6) for _ in range(len(angles))]
lowerLimit = 3

# Initialize the figure
plt.figure(figsize=(20, 10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Use a colormap
cmap = cm.get_cmap("viridis", len(angles))
colors = [cmap(i) for i in range(len(angles))]

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color=colors,
    alpha=0.6,
)

# Space between bar and label
labelPadding = 1

# Add labels
for bar, angle, height, label in zip(bars, angles, heights, ["Label1", "Label2", "Label3", "Label4", "Label5", "Label6", "Label7", "Label8", "Label9", "Label10"]):
    rotation = np.rad2deg(angle)
    alignment = "right" if np.pi / 2 <= angle < 3 * np.pi / 2 else "left"
    if alignment == "right":
        rotation += 180
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor",
        fontsize=10,  
        fontweight='bold',
        color="#333333",
    )

# Highlight the tallest bar
max_height_index = np.argmax(heights)
bars[max_height_index].set_edgecolor("gold")
bars[max_height_index].set_linewidth(4)

# Annotate the tallest bar
ax.annotate(
    "Max Height",
    xy=(angles[max_height_index], lowerLimit + heights[max_height_index] + labelPadding),
    xytext=(angles[max_height_index], lowerLimit + heights[max_height_index] + labelPadding + 2),
    arrowprops=dict(facecolor='black', shrink=0.05),
    fontsize=12,
    color='darkred',
    fontweight='bold',
)

# Add gridlines
#ax.grid(color='gray', linestyle='--', linewidth=0.7, alpha=0.6)

# Add title
plt.title(
    "Polar Bar Chart", 
    va='center', 
    pad=20, 
    fontsize=24, 
    fontweight='bold', 
    color="#4A4A4A"
)

# Show plot
plt.show()
# Out:
# C:\Users\Anna\AppData\Local\Temp\ipykernel_20972\490515328.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("viridis", len(angles))
